# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import cm

# %%
emb = np.load("../umap1.npy")
Y = np.load("../Y.npy")

print(emb.shape)
print(Y.shape)
# Out:
# (10000, 2)
# (10000,)

# %%
colormap = cm.get_cmap('tab10')
colormap(Y)
# Out:
# array([[0.49803922, 0.49803922, 0.49803922, 1.        ],
#        [0.17254902, 0.62745098, 0.17254902, 1.        ],
#        [1.        , 0.49803922, 0.05490196, 1.        ],
#        ...,
#        [0.58039216, 0.40392157, 0.74117647, 1.        ],
#        [0.54901961, 0.3372549 , 0.29411765, 1.        ],
#        [0.89019608, 0.46666667, 0.76078431, 1.        ]])

# %%
plt.figure(figsize=(16, 12))
vis = plt.scatter(emb[:, 0], emb[:, 1], alpha = 0.1, marker = '.')#, c = Y, cmap = colormap)
plt.colorbar(vis)
plt.title("No ML-SAT, raw 20-ANN")
# Out:
# Text(0.5, 1.0, 'No ML-SAT, raw 20-ANN')

# %%
plt.figure(figsize=(16, 12))
vis = plt.scatter(emb[:, 0], emb[:, 1], c = Y, alpha = 0.4, cmap = colormap)
# vis = plt.scatter(emb[:, 0], emb[:, 1], alpha = 0.2)
plt.colorbar(vis)
